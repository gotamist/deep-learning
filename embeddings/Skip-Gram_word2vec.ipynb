# %% [markdown]
# # Skip-gram word2vec
#
# Continuos bag of words (CBOW) and Skip-gram are the two most common ways currently in use to train word2vec on a corpus.  Here, I use TensorFlow to implement the word2vec algorithm using the skip-gram architecture.  This will come in handy when dealing with things like machine translation.
#
# ## Some resources
#
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# There may be tens of thousands of words in a corpus. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a waste of computation.
#
# To solve this problem and greatly increase the efficiency of our networks, word embeddings are useful. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then we can extract it.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

# %%
if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that the data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. We're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# Every example is trained using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Documentation of the Tensorflow function to do this.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# Use Thushan Ganegedara's implementation here to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 1000 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 5000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8_Jan2019.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 55.4774 0.1840 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 52.0311 0.1825 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 48.3301 0.1820 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 47.1674 0.1817 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 46.0215 0.0679 sec/batch
# Nearest to s: farrar, yardbirds, bic, downloadable, inroads, pulitzer, kamehameha, roleplay,
# Nearest to more: interceptors, resettle, non, gretchen, xvii, also, fansite, dt,
# Nearest to between: iwama, collectible, fulfilling, filters, mama, spatial, unused, doj,
# Nearest to been: bakery, infuse, community, kuna, pyramid, electromagnetic, extraordinary, josephus,
# Nearest to are: recorders, retrospectively, use, commonly, derivation, pineal, cosmology, kolkata,
# Nearest to be: deteriorates, deflection, russell, homosexuality, sdp, case, performing, swapped,
# Nearest to where: linked, patented, technicolor, prickly, retcon, triangle, godel, slight,
# Nearest to states: government, verus, violations, arian, saddam, outlawing, legislative, national,
# Nearest to brother: toil, extends, haggadah, td, larval, referring, pius, concluding,
# Nearest to mean: disintegration, decapitate, presidentially, cartridge, sequence, cnrs, keystrokes, alexandra,
# Nearest to pope: darya, redshifted, benjamin, salar, filkers, rediscovery, decline, potash,
# Nearest to grand: leandro, brookline, stonewall, malebranche, baba, modem, sprout, awry,
# Nearest to egypt: equalling, porch, shootouts, yoshino, foremost, johnston, chestnuts, lebanon,
# Nearest to alternative: clinical, mateo, jaeger, tis, brush, hanjour, gentiles, upheaval,
# Nearest to quite: castrated, dominance, mounts, masashi, presidencies, experimental, notoc, mortimer,
# Nearest to resources: bronze, fiat, files, improves, walther, leases, querying, small,
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 44.6991 0.1834 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 44.0754 0.1827 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 43.7566 0.1816 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 43.2645 0.1821 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 42.4637 0.1359 sec/batch
# Nearest to s: freemasonry, yardbirds, bubbling, downloadable, pc, ville, by, pulitzer,
# Nearest to more: interceptors, also, resettle, cockroach, gretchen, stetson, melancholia, minimis,
# Nearest to between: iwama, fulfilling, subkeys, factions, pharyngeal, facto, sailing, acquiesce,
# Nearest to been: infuse, kuna, bakery, community, disappointing, spec, filming, extraordinary,
# Nearest to are: commonly, occurring, grows, kolkata, retrospectively, recorders, pineal, subatomic,
# Nearest to be: deteriorates, thing, evaluates, homosexuality, swapped, elwes, case, deflection,
# Nearest to where: technicolor, retcon, linked, azusa, haemophiliac, athletics, litres, patented,
# Nearest to states: verus, outlawing, national, violations, parks, taunus, government, esaf,
# Nearest to brother: toil, daughter, pius, horeb, haggadah, goldwyn, prussia, reginald,
# Nearest to mean: disintegration, decapitate, cnrs, presidentially, centripetal, roasts, nanette, mangroves,
# Nearest to pope: xii, darya, papal, comnenus, church, salar, tremblay, didache,
# Nearest to grand: brookline, leandro, stonewall, fateful, lands, hicks, isidore, pegmatite,
# Nearest to egypt: equalling, lebanon, yoshino, foremost, neisse, burgos, bouchard, iraq,
# Nearest to alternative: clinical, mateo, jaeger, warehousing, counseling, tapu, grilled, tis,
# Nearest to quite: castrated, dominance, anima, enumerate, ecoregion, masashi, presidencies, kept,
# Nearest to resources: bronze, crannog, bauxite, files, improves, fiat, bodmin, sparse,
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 41.8408 0.1824 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 41.7808 0.1802 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 41.6791 0.1824 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 41.3642 0.0203 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 40.8213 0.1826 sec/batch
# Nearest to s: freemasonry, unmixed, by, yardbirds, beginning, rendered, theater, gwendolyn,
# Nearest to more: also, interceptors, resettle, sysop, cockroach, glottalized, accessibility, afrika,
# Nearest to between: iwama, subkeys, factions, bandanese, tectonic, fulfilling, vukovar, facto,
# Nearest to been: infuse, kuna, filming, disappointing, administered, spec, threats, renamed,
# Nearest to are: kolkata, is, grows, different, commonly, occurring, bailiwicks, toasted,
# Nearest to be: deteriorates, evaluates, thing, babies, budgeted, case, airship, deflection,
# Nearest to where: technicolor, haemophiliac, permanently, athletics, litres, azusa, slight, retcon,
# Nearest to states: outlawing, taunus, concession, constitution, abolitionists, preserve, albany, formally,
# Nearest to brother: toil, horeb, daughter, haggadah, mcneil, reginald, prussia, diocletian,
# Nearest to mean: disintegration, centripetal, bother, roasts, cnrs, decapitate, mangroves, nanette,
# Nearest to pope: xii, papal, darya, comnenus, ix, gregory, bishops, bishoprics,
# Nearest to grand: brookline, isidore, schindler, fateful, leandro, stonewall, tirol, pennock,
# Nearest to egypt: lebanon, yoshino, equalling, porch, khafre, fatwa, austroasiatic, seleucid,
# Nearest to alternative: clinical, warehousing, counseling, tis, mateo, distinctives, millet, tapu,
# Nearest to quite: castrated, dominance, ecoregion, kept, anima, umpire, subpages, only,
# Nearest to resources: bauxite, bronze, logging, sustainable, crannog, files, improves, sparse,
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 40.5158 0.1830 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 40.7151 0.1825 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 40.5917 0.1827 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 40.2328 0.0883 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 39.8413 0.1833 sec/batch
# Nearest to s: freemasonry, caine, kremvax, unmixed, downloadable, by, actual, yardbirds,
# Nearest to more: also, resettle, accessibility, glottalized, interceptors, anarchy, cockroach, sysop,
# Nearest to between: iwama, subkeys, bandanese, ideologically, factions, fulfilling, vukovar, warranties,
# Nearest to been: sustained, disappointing, pyramid, caballus, threats, kuna, infuse, claimed,
# Nearest to are: is, there, have, different, living, all, commonly, kolkata,
# Nearest to be: thing, babies, case, evaluates, enough, it, deteriorates, bonus,
# Nearest to where: athletics, haemophiliac, permanently, litres, technicolor, bribed, wen, slight,
# Nearest to states: united, preserve, abolitionists, outlawing, hants, formally, albany, concession,
# Nearest to brother: daughter, toil, horeb, liaisons, mcneil, married, mckeon, prussia,
# Nearest to mean: centripetal, disintegration, roasts, decapitate, bother, cnrs, car, nanette,
# Nearest to pope: xii, papal, bishops, gregory, encyclical, darya, comnenus, chlorus,
# Nearest to grand: brookline, isidore, tirol, schindler, fateful, pennock, stratocaster, corvette,
# Nearest to egypt: lebanon, khafre, fatwa, yoshino, equalling, austroasiatic, porch, coptic,
# Nearest to alternative: clinical, distinctives, counseling, tis, warehousing, bray, mateo, jaeger,
# Nearest to quite: castrated, dominance, ecoregion, subpages, kept, ensemble, anima, breakaway,
# Nearest to resources: bauxite, bronze, sustainable, logging, potash, sparse, improves, crannog,
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 39.9501 0.1837 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 39.9326 0.1829 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 39.9016 0.1820 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 39.4965 0.1567 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 39.1928 0.1824 sec/batch
# Nearest to s: caine, of, freemasonry, kremvax, the, margraves, by, john,
# Nearest to more: also, resettle, very, interceptors, accessibility, popular, anarchy, result,
# Nearest to between: iwama, subkeys, factions, ideologically, fulness, fulfilling, bandanese, is,
# Nearest to been: disappointing, threats, sustained, claimed, abbey, have, horus, caballus,
# Nearest to are: is, all, have, there, some, living, different, or,
# Nearest to be: babies, least, for, it, cy, to, thing, juicy,
# Nearest to where: athletics, permanently, litres, haemophiliac, slight, jewell, scavengers, bribed,
# Nearest to states: united, preserve, hants, abolitionists, specialise, formally, outlawing, bouquet,
# Nearest to brother: daughter, liaisons, horeb, toil, teens, mckeon, mcneil, inherit,
# Nearest to mean: centripetal, disintegration, roasts, car, bother, contours, cnrs, decapitate,
# Nearest to pope: xii, papal, encyclical, gregory, darya, antipope, hilbert, bishops,
# Nearest to grand: isidore, remey, tirol, slam, brookline, schindler, simitis, stratocaster,
# Nearest to egypt: lebanon, khafre, fatwa, austroasiatic, coptic, porch, equalling, yoshino,
# Nearest to alternative: clinical, distinctives, warehousing, tis, bray, counseling, universally, mateo,
# Nearest to quite: castrated, ensemble, dominance, mastery, subpages, umpire, breakaway, kirkwood,
# Nearest to resources: bauxite, bronze, logging, improves, sustainable, woollen, resource, contributor,
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 39.5019 0.1818 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 39.6151 0.1822 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 39.2274 0.0407 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 38.9012 0.1825 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 38.8899 0.1826 sec/batch
# Nearest to s: the, of, and, caine, a, by, kremvax, in,
# Nearest to more: also, resettle, very, saavedra, popular, expressivity, non, than,
# Nearest to between: iwama, subkeys, ideologically, zariski, fulness, is, factions, filters,
# Nearest to been: have, has, claimed, renamed, disappointing, period, cornwall, caballus,
# Nearest to are: is, all, have, there, some, or, living, other,
# Nearest to be: least, it, cy, to, for, therefore, juicy, that,
# Nearest to where: athletics, permanently, an, litres, jewell, haemophiliac, compressible, erg,
# Nearest to states: united, preserve, abolitionists, formally, biochemists, specialise, shooters, hants,
# Nearest to brother: toil, daughter, teens, cousin, horeb, enactment, liaisons, inherit,
# Nearest to mean: centripetal, roasts, disintegration, car, bother, elul, decapitate, contours,
# Nearest to pope: xii, papal, antipope, encyclical, gregory, darya, bishops, pachomius,
# Nearest to grand: auto, remey, isidore, knebworth, slam, tirol, corvette, laughed,
# Nearest to egypt: coptic, fatwa, lebanon, austroasiatic, equalling, porch, khafre, inscriptions,
# Nearest to alternative: clinical, distinctives, warehousing, bray, releases, counseling, universally, inhibitor,
# Nearest to quite: ensemble, castrated, subpages, dominance, kirkwood, mastery, breakaway, umpire,
# Nearest to resources: bauxite, sustainable, logging, resource, improves, bronze, contributor, woollen,
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 39.1400 0.1841 sec/batch
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 39.1631 0.1832 sec/batch
# Epoch 8/10 Iteration: 33000 Avg. Training loss: 38.9104 0.1076 sec/batch
# Epoch 8/10 Iteration: 34000 Avg. Training loss: 38.6179 0.1826 sec/batch
# Epoch 8/10 Iteration: 35000 Avg. Training loss: 38.7296 0.1824 sec/batch
# Nearest to s: of, the, and, a, in, caine, was, by,
# Nearest to more: also, very, resettle, popular, has, penni, than, extremely,
# Nearest to between: iwama, zariski, fact, ideologically, sets, subkeys, and, bootp,
# Nearest to been: have, has, claimed, most, although, recent, known, disappointing,
# Nearest to are: is, have, all, there, and, some, or, living,
# Nearest to be: to, it, for, or, as, therefore, only, that,
# Nearest to where: that, erg, jewell, permanently, an, athletics, same, at,
# Nearest to states: united, bouquet, shooters, abolitionists, taney, preserve, biochemists, formally,
# Nearest to brother: cousin, teens, toil, daughter, enactment, aunt, liaisons, inherit,
# Nearest to mean: centripetal, roasts, kei, elul, disintegration, car, papp, shall,
# Nearest to pope: xii, papal, encyclical, gregory, darya, antipope, pachomius, pontiff,
# Nearest to grand: remey, auto, slam, knebworth, upc, isidore, tirol, prophetic,
# Nearest to egypt: fatwa, coptic, lebanon, equalling, khafre, porch, nasser, austroasiatic,
# Nearest to alternative: clinical, warehousing, distinctives, counseling, disclaimer, releases, nlm, fax,
# Nearest to quite: ensemble, kirkwood, subpages, castrated, breakaway, paddy, sixxs, fellin,
# Nearest to resources: bauxite, improves, bronze, resource, sustainable, woollen, potash, logging,
# Epoch 8/10 Iteration: 36000 Avg. Training loss: 38.7805 0.1837 sec/batch
# Epoch 8/10 Iteration: 37000 Avg. Training loss: 38.7883 0.1829 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 38.6550 0.1756 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 38.4314 0.1823 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 38.6341 0.1829 sec/batch
# Nearest to s: of, the, and, in, a, was, for, by,
# Nearest to more: also, resettle, very, than, extremely, most, popular, and,
# Nearest to between: morphological, zariski, and, hymen, there, iwama, leaderships, fact,
# Nearest to been: have, has, claimed, known, recent, most, although, disappointing,
# Nearest to are: is, have, some, all, there, and, or, living,
# Nearest to be: to, it, for, only, or, were, least, therefore,
# Nearest to where: erg, that, at, jewell, an, permanently, same, athletics,
# Nearest to states: united, shooters, taney, u, kingdom, bouquet, preserve, formally,
# Nearest to brother: teens, sons, liaisons, cousin, daughter, toil, rumpus, aunt,
# Nearest to mean: roasts, centripetal, elul, kei, sec, decapitate, homogenous, papp,
# Nearest to pope: xii, papal, antipope, darya, encyclical, gregory, pachomius, pontiff,
# Nearest to grand: auto, remey, slam, upc, isidore, pennock, knebworth, tirol,
# Nearest to egypt: coptic, fatwa, nile, lebanon, nasser, equalling, khafre, austroasiatic,
# Nearest to alternative: disclaimer, clinical, limnic, warehousing, releases, nlm, distinctives, prove,
# Nearest to quite: ensemble, masurian, paddy, umpire, kirkwood, castrated, varying, refutable,
# Nearest to resources: bauxite, resource, improves, bronze, extremes, woollen, sustainable, bata,
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 38.6829 0.1841 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 38.3921 0.0602 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 38.2505 0.1836 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 38.3429 0.1814 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 38.3881 0.1831 sec/batch
# Nearest to s: of, and, the, in, a, for, is, by,
# Nearest to more: also, and, than, of, very, most, in, are,
# Nearest to between: and, there, significant, fact, is, hymen, the, morphological,
# Nearest to been: have, has, most, although, known, claimed, recent, also,
# Nearest to are: is, have, and, all, or, some, for, there,
# Nearest to be: to, for, it, or, only, can, a, such,
# Nearest to where: erg, that, at, dispossessed, permanently, is, when, but,
# Nearest to states: united, u, preserve, formally, shooters, taney, us, atone,
# Nearest to brother: sons, cousin, teens, rumpus, aunt, daughter, liaisons, toil,
# Nearest to mean: roasts, kei, centripetal, elul, sec, shall, ingrid, decapitate,
# Nearest to pope: xii, papal, antipope, encyclical, darya, gregory, pachomius, pontiff,
# Nearest to grand: auto, remey, slam, upc, gos, teeming, prix, tirol,
# Nearest to egypt: coptic, nile, fatwa, austroasiatic, humoral, equalling, khafre, lebanon,
# Nearest to alternative: clinical, disclaimer, warehousing, nlm, distinctives, prove, releases, cantabile,
# Nearest to quite: masurian, ensemble, eats, not, subpages, isn, it, kirkwood,
# Nearest to resources: bauxite, resource, improves, extremes, bata, sustainable, potash, logging,
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 38.3836 0.1839 sec/batch

# %% [markdown]
# Restore the trained network if needed:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8_Jan2019.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. [This post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) explains more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 200
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
